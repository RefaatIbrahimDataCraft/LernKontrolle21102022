# %%
#Import 
# Step1
import pandas as pd
import numpy as np 
data = pd.read_csv("Dataset_file.csv")
data.head(4)
# Out:
# C:\Users\Dell XPS\AppData\Local\Temp\ipykernel_30932\4273633171.py:4: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Dataset_file.csv")
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# ...

# %%
#Step2
# Wie viel NaN hat jeder Spalte!? Gib anschließend die 10 größten Werte aus
data.isnull().sum().nlargest(10)
# Out:
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# Permit Expiration Date            51880
# dtype: int64

# %%
# Step3
delete_data = data[data.columns[data.isna().sum()/data.shape[0] < 0.5]] # 50% = 0.5
delete_data.head(5)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       Ellis            St
# 1           04/19/2016  0306  007            440       Geary            St
# 2           05/27/2016  0595  203           1647     Pacific            Av
# 3           11/07/2016  0156  011           1230     Pacific            Av
# 4           11/28/2016  0342  001            950      Market            St
#
#                                          Description  ... Plansets  \
# ...

# %%
# Step4 percentage of NAN Values in the entire dataframe
percentage = data.isnull().sum().sum() * 100 / data.size
percentage
# Out:
# 26.260023150584026

# %%
#Step4 with 50%
percentage = delete_data.isnull().sum().sum() * 100 / len(delete_data)
percentage
# Out:
# 289.9542483660131

# %%
#Step5
# Import Library Missingno 
import missingno as msno
msno.matrix(delete_data)
# Out:
# <AxesSubplot: >

# %%
# Step6
#Step1
import pandas
pandas.options.mode.chained_assignment = None  # default='warn', ffill = forward fill function 
delete_data['Existing Use'] = delete_data['Existing Use'].fillna(method='ffill')
delete_data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# ...

# %%
#Step2 
# restliche NaNs mit 0 füllen
delete_data_with_0 = delete_data.fillna(0)
delete_data_with_0
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# ...

# %%
#Step7
stories_data = delete_data["Number of Existing Stories"].fillna(1)
stories_data
# Out:
# 0         6.0
# 1         7.0
# 2         6.0
# 3         2.0
# 4         3.0
#          ...
# 198895    1.0
# 198896    4.0
# 198897    1.0
# 198898    1.0
# 198899    1.0
# Name: Number of Existing Stories, Length: 198900, dtype: float64

# %%
#Step8
units_data = delete_data["Existing Units"].fillna(delete_data["Existing Units"].max())
units_data
# Out:
# 0          143.0
# 1         1907.0
# 2           39.0
# 3            1.0
# 4         1907.0
#            ...
# 198895    1907.0
# 198896       4.0
# 198897    1907.0
# 198898    1907.0
# 198899    1907.0
# Name: Existing Units, Length: 198900, dtype: float64

# %%
# Step9 interpolate 
poly_plansets=delete_data.Plansets.interpolate(method= "polynomial", order= 2)
poly_plansets
# Out:
# 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#             ...
# 198895    0.779835
# 198896    2.000000
# 198897         NaN
# 198898         NaN
# 198899         NaN
# Name: Plansets, Length: 198900, dtype: float64

# %%
# Step10
#Lade die Aktualisierte Notebook Auf den Server (Github)
# OK. I have DONE it.Alhamdullah
